# %% [markdown]
# <a href="https://colab.research.google.com/github/Ron-Wu/Machine-learning-0602/blob/main/05face_identification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install mtcnn
# Out:
# Collecting mtcnn
#   Downloading https://files.pythonhosted.org/packages/09/d1/2a4269e387edb97484157b872fa8a1953b53dcafbe4842a1967f549ac5ea/mtcnn-0.1.1-py3-none-any.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 26.2MB/s
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (2.4.3)
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (4.1.2.30)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras>=2.0.0->mtcnn) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras>=2.0.0->mtcnn) (1.19.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras>=2.0.0->mtcnn) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras>=2.0.0->mtcnn) (3.1.0)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py->keras>=2.0.0->mtcnn) (1.5.2)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1

# %%
import pickle
import keras
from keras.models import load_model
import cv2
from glob import glob
import matplotlib.pyplot as plt
import numpy as np
import os
from mtcnn import MTCNN
from pprint import pprint

# %%
folder_path = '/content/drive/MyDrive/勞動部/03-CNN-Applications/Face_recognition'

# %%
# read db
with open(os.path.join(folder_path, 'db.pickle'), 'rb') as file:
    db = pickle.load(file)
embeddings = db['embeddings']
names = db['names']

# %%
raw_img = cv2.imread(os.path.join(folder_path, 'test_img/face1.jpg'))[:,:,::-1]
plt.imshow(raw_img)

# %%
detector = MTCNN()
feature_extractor = load_model(os.path.join(folder_path, 'facenet.h5'))
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# detect face
def detect_faces(img):
    face_imgs = []
    results = detector.detect_faces(img)
    # extract the bounding box from the first face
    pprint(f'face count: {len(results)}' )
    pprint(results)
    for i in range(len(results)):
        x1, y1, width, height = results[i]['box']
        x2, y2 = x1 + width, y1 + height
        patch = img[y1:y2, x1:x2] # crop face
        face_imgs.append(patch)
    return face_imgs

faces = detect_faces(raw_img)
# Out:
# 'face count: 3'
# [{'box': [344, 79, 105, 142],
#   'confidence': 0.9984662532806396,
#   'keypoints': {'left_eye': (353, 139),
#                 'mouth_left': (370, 192),
#                 'mouth_right': (408, 184),
#                 'nose': (369, 174),
#                 'right_eye': (397, 130)}},
#  {'box': [376, 399, 26, 30],
#   'confidence': 0.9473415613174438,
#   'keypoints': {'left_eye': (387, 408),
#                 'mouth_left': (384, 420),
#                 'mouth_right': (389, 421),
#                 'nose': (391, 416),
#                 'right_eye': (394, 409)}},
#  {'box': [486, 157, 35, 46],
#   'confidence': 0.9285464882850647,
#   'keypoints': {'left_eye': (501, 172),
#                 'mouth_left': (504, 190),
#                 'mouth_right': (517, 190),
#                 'nose': (514, 180),
#                 'right_eye': (516, 171)}}]

# %%
# all face shapes
for f in faces:
  print(f.shape)
# Out:
# (142, 105, 3)
# (30, 26, 3)
# (46, 35, 3)

# %%
# show all faces
for face in faces:
    plt.imshow(face)
    plt.show()

# %%
# Standardization
def preprocess(imgs): 
    for i in range(imgs.shape[0]):
        # standardization
        img = imgs[i]
        mean, std = img.mean(), img.std()
        img = (img - mean) / std
        imgs[i] = img
    return imgs

# %%
face = faces[0]
face = cv2.resize(face, (160, 160))
model_input = np.zeros((1, 160, 160, 3))
model_input[0] = face
model_input = preprocess(model_input)
query_embedding = feature_extractor.predict(model_input)
query_embedding.shape
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efd1005e950> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efd1005e950>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efd1005e950> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efd1005e950>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efd1005e560> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efd1005e560>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efd1005e560> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efd1005e560>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efd1005e710> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efd1005e710>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efd1005e710> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efd1005e710>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efd1005ed40> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efd1005ed40>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efd1005ed40> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efd1005ed40>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efd1005ee60> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efd1005ee60>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efd1005ee60> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efd1005ee60>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efd1005ef80> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efd1005ef80>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efd1005ef80> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efd1005ef80>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcd2062050> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062050>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcd2062050> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062050>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcd2062200> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062200>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcd2062200> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062200>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcd2062320> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062320>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcd2062320> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062320>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcd2062440> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062440>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcd2062440> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062440>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcd2062560> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062560>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcd2062560> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062560>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcd2062680> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062680>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcd2062680> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062680>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcd20627a0> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd20627a0>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcd20627a0> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd20627a0>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcd20628c0> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd20628c0>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcd20628c0> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd20628c0>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcd20629e0> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd20629e0>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcd20629e0> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd20629e0>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcd2062a70> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062a70>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcd2062a70> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062a70>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcd2062c20> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062c20>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcd2062c20> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062c20>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcd2062d40> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062d40>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcd2062d40> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062d40>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcd2062e60> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062e60>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcd2062e60> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062e60>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcd2062f80> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062f80>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcd2062f80> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcd2062f80>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7efcc2718050> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcc2718050>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7efcc2718050> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7efcc2718050>: no matching AST found
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (1, 128)

# %%
query_embedding = query_embedding[0]
query_embedding
# Out:
# array([ 0.06799047,  0.12125826,  1.6803017 ,  0.2266227 , -0.19772406,
#        -0.5266149 ,  1.3997647 , -1.0153    , -1.004349  , -0.14255561,
#        -0.89007926, -0.08877093, -0.850235  ,  0.14866312,  1.7950583 ,
#        -0.2586607 , -3.7028863 ,  0.66567945, -1.6760983 , -0.28878063,
#         0.6151947 , -1.6937041 ,  1.674318  ,  1.0957053 , -0.55945563,
#        -0.845497  , -0.7542733 , -1.3719426 ,  0.831037  ,  1.7763109 ,
#         0.8968804 , -0.40917367,  0.24641258,  0.74323225, -0.6018077 ,
#        -1.5276098 ,  1.3590082 , -1.5484148 , -0.3125031 , -0.05612363,
#         0.5156494 , -0.17581509, -1.0397735 , -0.38326576, -0.43450555,
#         1.2091308 ,  0.02058909,  0.89738286, -0.49612463,  0.7863574 ,
#        -0.5857703 , -1.1784369 ,  0.5250691 ,  0.9866797 ,  0.8502983 ,
#         0.7287936 , -0.3907556 ,  0.445546  ,  0.45927757,  1.4472904 ,
#        -0.55583674,  0.23093455,  0.00834765, -0.6252112 , -0.9833476 ,
#         0.9170231 , -1.1411942 ,  1.309362  ,  0.8001035 ,  0.3836709 ,
#        -0.44169483,  0.03396869,  1.5431392 ,  0.82961076, -1.8057799 ,
#        -0.44713375, -2.2568982 , -0.85213125, -0.5530524 , -0.24144357,
#        -0.24689245, -1.5826402 , -0.40552762,  0.4586189 ,  1.3633451 ,
#        -1.0684137 ,  0.0744492 ,  1.6134101 ,  1.2486604 ,  0.5916741 ,
#         0.2672232 ,  0.9264707 ,  0.55636245, -0.04871926, -0.97088325,
#         1.7733921 ,  0.5476331 , -0.2896493 ,  0.81131613, -1.1334099 ,
#        -1.3087883 , -0.82379425, -0.42288578, -0.29800233,  1.3096677 ,
#        -2.1853433 , -0.04162014,  0.1736651 ,  0.6198457 ,  0.62792224,
#        -0.39518595, -1.267895  ,  0.33599797, -2.6449656 ,  0.08341309,
#         0.6450621 ,  0.93009424,  0.2581812 ,  0.36665937, -0.23585455,
#         0.3846311 , -1.2946271 ,  0.3227347 , -0.3920152 , -1.2174338 ,
#         0.34902045, -1.2442676 ,  0.62550575], dtype=float32)

# %%
def euclidean_distance(x, y):
    sum_square = np.sum(np.square(x - y), keepdims=True)
    return np.sqrt(sum_square)

# %%
# Get all distances from database embeddings 
distances = np.zeros((len(embeddings)))
for i, embed in enumerate(embeddings):
    distance = euclidean_distance(embed, query_embedding)
    distances[i] = distance

# %%
print(distances[:10])
plt.hist(distances)
plt.show()
# Out:
# [ 8.55213928 14.27076054 15.66152763 15.79713249 14.56616211]

# %%
np.argmin(distances)
# Out:
# 0

# %%
idx_min = np.argmin(distances)
distances[idx_min], names[idx_min]
# Out:
# (8.552139282226562, 'gal_gadot')

# %%
def face_id(filename, IMG_SIZE=160):
    raw_img = cv2.imread(os.path.join(folder_path, 'test_img', filename))[:,:,::-1]
    faces = detect_faces(raw_img)
    if len(faces) == 0:
        print('No face')
        return
    else:
        # get face embeddings
        face = faces[0]

        face = cv2.resize(face, (IMG_SIZE, IMG_SIZE))
        model_input = np.zeros((1, IMG_SIZE, IMG_SIZE, 3))
        model_input[0] = face
        model_input = preprocess(model_input)
        query_embeddings = feature_extractor.predict(model_input)
        query_embedding = query_embeddings[0]
        
        # compute distance
        distances = np.zeros((len(embeddings)))
        for i, embed in enumerate(embeddings):
            distance = euclidean_distance(embed, query_embedding)
            distances[i] = distance
        plt.hist(distances)
        plt.show()
        # find min distance    
        idx_min = np.argmin(distances)
        distance, name = distances[idx_min], names[idx_min]
        print(name, distance)
        plt.imshow(raw_img)
        plt.show()

# %%
face_id('face1.jpg') # 可以測試face1~9.jpg
# Out:
# 'face count: 3'
# [{'box': [344, 79, 105, 142],
#   'confidence': 0.9984662532806396,
#   'keypoints': {'left_eye': (353, 139),
#                 'mouth_left': (370, 192),
#                 'mouth_right': (408, 184),
#                 'nose': (369, 174),
#                 'right_eye': (397, 130)}},
#  {'box': [376, 399, 26, 30],
#   'confidence': 0.9473415613174438,
#   'keypoints': {'left_eye': (387, 408),
#                 'mouth_left': (384, 420),
#                 'mouth_right': (389, 421),
#                 'nose': (391, 416),
#                 'right_eye': (394, 409)}},
#  {'box': [486, 157, 35, 46],
#   'confidence': 0.9285464882850647,
#   'keypoints': {'left_eye': (501, 172),
#                 'mouth_left': (504, 190),
#                 'mouth_right': (517, 190),
#                 'nose': (514, 180),
#                 'right_eye': (516, 171)}}]
# gal_gadot 8.552139282226562
